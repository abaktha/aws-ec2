# %%
# %pwd
# Out:
# u'C:\\Users\\Aravindh\\aws-ec2'

# %%
import os, sys
current_dir = os.getcwd()
HOME = 'c:/Users/Aravindh/'
#HOME = '/home/ubuntu'
LESSON_HOME_DIR = current_dir
DATA_HOME_DIR= current_dir+'/data/redux'
sys.path.append(os.path.expanduser('current_dir+/utils/'))

# %%
from Vgg import *
import cv2
import numpy as np
import glob
from matplotlib import pyplot as plt
# %matplotlib inline
# Out:
# Using Theano backend.

# %%
model = Vgg()
model.load_weights(HOME+'/models/vgg16.h5')
model.load_imagenet_class_index(HOME+'/models/imagenet_class_index.json')
# Out:
# Hello from Vgg()
# NameErrorTraceback (most recent call last)
# <ipython-input-3-73fd06458bb4> in <module>()
# ----> 1 model = Vgg()
#       2 model.load_weights(HOME+'/models/vgg16.h5')
#       3 model.load_imagenet_class_index(HOME+'/models/imagenet_class_index.json')
#
# C:\Users\Aravindh\aws-ec2\utils\Vgg.py in __init__(self)
#      13     def __init__(self):
#      14         print "Hello from Vgg()"
# ---> 15         self.create()  # create model
#      16
#      17     def create(self):
#
# C:\Users\Aravindh\aws-ec2\utils\Vgg.py in create(self)
#      60         model.add(Dropout(0.5))
#      61         model.add(Dense(1000, activation='softmax'))  # layer16 fully connected (inner_product)
# ---> 62         self.compile(lr=0.01)
#      63
#      64     def load_imagenet_class_index(self, imagenet_file):
#
# C:\Users\Aravindh\aws-ec2\utils\Vgg.py in compile(self, lr)
#      90     def compile(self, lr=0.001):
#      91         sgd = SGD(lr, decay=1e-6, momentum=0.9, nesterov=True)
# ---> 92         model.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['accuracy'])
#      93
#
# NameError: global name 'model' is not defined

# %%
for imgfile in glob.glob(HOME+'data/redux/train/*/*.251*.jpg'):
    img = cv2.imread(imgfile)
    out=model.predict(img)
    print(model.imagenet_index[str(np.argmax(out))]) # index of max value
# Out:
# [u'n02124075', u'Egyptian_cat']
# [u'n04462240', u'toyshop']
# [u'n02883205', u'bow_tie']
# [u'n02124075', u'Egyptian_cat']
# [u'n02098286', u'West_Highland_white_terrier']
# [u'n02123045', u'tabby']
# [u'n02124075', u'Egyptian_cat']
# [u'n02328150', u'Angora']
# [u'n02124075', u'Egyptian_cat']
# [u'n02127052', u'lynx']
# [u'n02123045', u'tabby']
# [u'n02106662', u'German_shepherd']
# [u'n02099712', u'Labrador_retriever']
# [u'n02106662', u'German_shepherd']
# [u'n02098105', u'soft-coated_wheaten_terrier']
# [u'n02099712', u'Labrador_retriever']
# [u'n02093256', u'Staffordshire_bullterrier']
# [u'n02088364', u'beagle']
# [u'n02093256', u'Staffordshire_bullterrier']
# [u'n02091134', u'whippet']
# [u'n02099712', u'Labrador_retriever']
# [u'n02089078', u'black-and-tan_coonhound']

# %%
    plt.imshow(img)
