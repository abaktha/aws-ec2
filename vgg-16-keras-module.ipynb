# %%
from Vgg import *
import cv2
import numpy as np
import glob
from matplotlib import pyplot as plt
# %matplotlib inline
# Out:
# Using Theano backend.

# %%
model = Vgg()
model.load_weights('c:/Users/Aravindh/models/vgg16.h5')
# Out:
# Hello from Vgg()

# %%
for imgfile in glob.glob('c:/Users/Aravindh/data/redux/sample/train/*.jpg'):
    img = cv2.imread(imgfile)
    out=model.predict(img)
    print(model.imagenet_index[str(np.argmax(out))]) # index of max value
# Out:
# [u'n02124075', u'Egyptian_cat']

# %%
    plt.imshow(img)
