# %%
# %matplotlib inline

# %%
# pylab provides procedural interface to matplotlib plotting library
from matplotlib import pylab as plt
import seaborn as sns # seaborn defaults

# %% [markdown]
# Simple Plot

# %%
import numpy as np

# %%
x = np.linspace(-np.pi,np.pi,256,endpoint=True)
C,S = np.cos(x), np.sin(x)

# %%
# Create a figure of size 8x6 inches, 80 dots per inch
plt.figure(figsize=(8, 6), dpi=80, frameon=True)

# Create a new subplot from a grid of 1x1
plt.subplot(1, 1, 1)

#Plot cosine with a blue continuous line of width 1 (pixels)
plt.plot(x, C, color="blue", linewidth=1.0, linestyle="-", label="Cosine")
# Plot sine with a green continuous line of width 1 (pixels)
plt.plot(x, S, color="green", linewidth=1.0, linestyle="-", label="Sine")

# set x,y limits
plt.xlim(x.min()*1.1,x.max()*1.1)
plt.ylim(C.min(),C.max())

# Setting spines
ax = plt.gca()  # gca stands for 'get current axis'
ax.spines['right'].set_color('none') # remove right
ax.spines['top'].set_color('none') # remove top
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0)) # move to y=0
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0)) # move to x=0

#ax.xaxis.set_major_locator(plt.MultipleLocator(1.0))
#ax.xaxis.set_minor_locator(plt.MultipleLocator(0.1))
ax.yaxis.set_major_locator(plt.MultipleLocator(0.5))
ax.yaxis.set_minor_locator(plt.MultipleLocator(0.1))
ax.grid(which='major', axis='x', linewidth=0.75, linestyle='-', color='0.75')
ax.grid(which='minor', axis='x', linewidth=0.25, linestyle='-', color='0.75')
ax.grid(which='major', axis='y', linewidth=0.75, linestyle='-', color='0.75')
ax.grid(which='minor', axis='y', linewidth=0.25, linestyle='-', color='0.75')


# Set x,y ticks
#plt.xticks(np.linspace(-4, 4, 9, endpoint=True))
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
          [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
#plt.yticks(np.linspace(-1, 1, 5, endpoint=True))
plt.yticks([-1,0,1], [r'$1$', r'$0$', r'$1$'])


# Place legend
plt.legend(loc='upper left')

# Enhance label
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontsize(12)
    label.set_bbox(dict(facecolor='white', edgecolor='None', alpha=0.65))

    

#plt.show()

# %%
cdyn = .93
[v,f]=[np.arange(0.5,1.2,.1),np.arange(1200,2600,200)]

# %%
v,f
# Out:
# (array([ 0.5,  0.6,  0.7,  0.8,  0.9,  1. ,  1.1]),
#  array([1200, 1400, 1600, 1800, 2000, 2200, 2400]))

# %%
dyn = cdyn*v**2.4*f

# %%
perf = .83*f

# %%
perf
# Out:
# array([  996.,  1162.,  1328.,  1494.,  1660.,  1826.,  1992.])

# %%
plt.style.available
# Out:
# [u'seaborn-darkgrid',
#  u'seaborn-notebook',
#  u'classic',
#  u'seaborn-ticks',
#  u'grayscale',
#  u'bmh',
#  u'seaborn-talk',
#  u'dark_background',
#  u'ggplot',
#  u'fivethirtyeight',
#  u'seaborn-colorblind',
#  u'seaborn-deep',
#  u'seaborn-whitegrid',
#  u'seaborn-bright',
#  u'seaborn-poster',
#  u'seaborn-muted',
#  u'seaborn-paper',
#  u'seaborn-white',
#  u'seaborn-pastel',
#  u'seaborn-dark',
#  u'seaborn',
#  u'seaborn-dark-palette']

# %%
# Create a figure of size 8x6 inches, 80 dots per inch
plt.figure(figsize=(8, 6), dpi=80, frameon=True)
#plt.style.use('ggplot')

# Create a new subplot from a grid of 1x1
plt.subplot(1, 1, 1)
#plt.suptitle("Spec PPW",fontsize=14)
plt.title("Spec PPW")
plt.xlabel('CPU Power (mW)')
plt.ylabel('Spec Score')

#Plot cosine with a blue continuous line of width 1 (pixels)
#plt.plot(x, C, color="blue", linewidth=1.0, linestyle="-", label="Cosine")
# Plot sine with a green continuous line of width 1 (pixels)
#lt.plot(x, S, color="green", linewidth=1.0, linestyle="-", label="Sine")


# set x,y limits
plt.xlim(0,dyn.max()*1.2*1.3)
plt.ylim(0,perf.max()*1.2*1.3)

# Setting spines
ax = plt.gca()  # gca stands for 'get current axis'
ax.xaxis.set_major_locator(plt.MultipleLocator(500))
ax.xaxis.set_minor_locator(plt.MultipleLocator(100))
ax.yaxis.set_major_locator(plt.MultipleLocator(500))
ax.yaxis.set_minor_locator(plt.MultipleLocator(100))
ax.grid(which='major', axis='x', linewidth=0.75, linestyle='-', color='0.75')
ax.grid(which='minor', axis='x', linewidth=0.25, linestyle='-', color='0.75')
ax.grid(which='major', axis='y', linewidth=0.75, linestyle='-', color='0.75')
ax.grid(which='minor', axis='y', linewidth=0.25, linestyle='-', color='0.75')


#plt.scatter(dyn,perf)
plt.plot(dyn,perf,linewidth=1.0, linestyle="-", label="A1")
plt.plot(dyn*1.2,perf*1.2, linewidth=1.0, linestyle="-", label="A2")
plt.plot(dyn*1.2*1.2,perf*1.2*1.25, linewidth=1.0, linestyle="-", label="A3")

# Place legend
plt.legend(loc='lower right')

plt.text(dyn.max()+100,perf.max(),'A57')
plt.savefig('test')
